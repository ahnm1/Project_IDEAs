# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns
import seaborn.objects as so
# import plotly.graph_objects as go
# import chart_studio.plotly as py
# %load_ext autoreload
# %autoreload 2

# %%
df = pd.read_csv('merge/clean_konkurser_1994-2022_from_api.csv')
df
# Out:
#         date  layoffs
# 0    1994-01     3069
# 1    1994-02     3209
# 2    1994-03     2897
# 3    1994-04     2207
# 4    1994-05     2581
# ..       ...      ...
# 343  2022-08     3872
# 344  2022-09     1070
# 345  2022-10     1924
# 346  2022-11     1596
# 347  2022-12     1297
#
# [348 rows x 2 columns]

# %%
# fig = px.scatter(df, x='date', y='layoffs')
# fig.show()
# data = [go.Bar(
#     x = df['date'],
#     y = df['layoffs'])]

# py.iplot(data, filename='jupyter-basic_bar')

sns.scatterplot(df, x = df['date'], y = df['layoffs'])
# Out:
# <AxesSubplot: xlabel='date', ylabel='layoffs'>
